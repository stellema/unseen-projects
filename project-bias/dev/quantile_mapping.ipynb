# %%
import math

import numpy as np
import xarray as xr
import xsdba
import matplotlib.pyplot as plt

# %%
t = xr.cftime_range("2000-01-01", "2030-12-31", freq="D", calendar="noleap")
# Out:
# /var/folders/6v/vrpsky6j509dff7250jyg8240000gp/T/ipykernel_29665/3472942113.py:1: DeprecationWarning: cftime_range() is deprecated, please use xarray.date_range(..., use_cftime=True) instead.
#   t = xr.cftime_range("2000-01-01", "2030-12-31", freq="D", calendar="noleap")

# %%
s = np.arange(len(t))

# %%
math.floor(len(s) / 2)
# Out:
# 5657

# %%
# Create toy data to explore bias adjustment

ref = xr.DataArray(
    (
        -20 * np.cos(2 * np.pi * t.dayofyear / 365)
        + 2 * np.random.random_sample((t.size,))
        + 273.15
        + 0.1 * (t - t[0]).days / 365
    ),  # "warming" of 1K per decade,
    dims=("sample",),
    coords={"sample": s},
    attrs={"units": "K"},
)
sim = xr.DataArray(
    (
        -18 * np.cos(2 * np.pi * t.dayofyear / 365)
        + 2 * np.random.random_sample((t.size,))
        + 273.15
        + 0.11 * (t - t[0]).days / 365
    ),  # "warming" of 1.1K per decade
    dims=("sample",),
    coords={"sample": s},
    attrs={"units": "K"},
)

ref = ref.isel(sample=slice(0, math.floor(len(s) / 2))) 
hist = sim.sel(sample=slice(0, math.floor(len(s) / 2)))

ref.plot(label="Reference")
sim.plot(label="Model")
plt.legend()
plt.show()

# %%
QM = xsdba.EmpiricalQuantileMapping.train(
    ref, hist, nquantiles=15, group="sample", kind="+"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 QM = xsdba.EmpiricalQuantileMapping.train(
#       2     ref, hist, nquantiles=15, group="sample", kind="+"
#       3 )
#
# File ~/opt/anaconda3/envs/unseen/lib/python3.13/site-packages/xsdba/adjustment.py:283, in TrainAdjust.train(cls, ref, hist, **kwargs)
#     281 if not skip_checks:
#     282     if "group" in kwargs:
# --> 283         cls._check_inputs(ref, hist, group=kwargs["group"])
#     285     (ref, hist), train_units = cls._harmonize_units(ref, hist)
#     286 else:
#
# File ~/opt/anaconda3/envs/unseen/lib/python3.13/site-packages/xsdba/adjustment.py:105, in BaseAdjustment._check_inputs(cls, group, *inputs)
#     100         raise ValueError(
#     101             f"Multiple chunks along the main adjustment dimension {group.dim} is not supported."
#     102         )
#     104 # All calendars used by the inputs
# --> 105 calendars = {inda.time.dt.calendar for inda in inputs}
#     106 if not cls._allow_diff_calendars and len(calendars) > 1:
#     107     raise ValueError(
#     108         "Inputs are defined on different calendars,"
#     109         f" this is not supported for {cls.__name__} adjustment."
#     110     )
#
# File ~/opt/anaconda3/envs/unseen/lib/python3.13/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'DataArray' object has no attribute 'time'

# %%
scen = QM.adjust(sim, extrapolation="constant", interp="nearest")
